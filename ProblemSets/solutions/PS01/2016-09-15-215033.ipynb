# %%
import subprocess
import os

subprocess.call(["./hw1q1", ">tmp"])

house = open("tmp")

correct_house = [ "/\\", "/  \\" , "+----+" , "| .-.|" , "| | ||" , "+-+-++" ]

error_lines = 0
for line in house:
    if line.strip() != correct_house.pop(0):
        error_lines = error_lines + 1

if error_lines:
    points = 10 - 2*error_lines
    print "Sorry, " + error_lines + " lines of your house have errors in them. (" + points + "/10)"
else:
    print "Nice house. (10/10)"

house.close()
os.
